# %% [markdown]
# # **Computational Drug Discovery [Part 1] Download Bioactivity Data**
# In this Jupyter notebook, we are building a real-life **data science project** for **Computational Drug Disovery**. Particularly, we building a machine learning model using the ChEMBL bioactivity data.

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Installing the ChEMBL web service package so that we can retrieve bioactivity data from the [ChEMBL Database](https://www.ebi.ac.uk/chembl/).

# %%
! pip install chembl_webresource_client
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 6.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Importing Libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Coronavirus**

# %%
# Target search for Coronavirus
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6  [{'xref_id': 'P0C6U8', 'xref_name': None, 'xre...
# 7                                                 []
# 8  [{'xref_id': 'P0C6X7', 'xref_name': None, 'xre...
# 9                                                 []
#
#                                             organism  \
# 0                                        Coronavirus
# 1                                   SARS coronavirus
# 2                                 Feline coronavirus
# 3                                 Murine coronavirus
# 4                             Human coronavirus 229E
# 5                             Human coronavirus OC43
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for SARS coronavirus 3C-like proteinase (seventh entry)**

# %% [markdown]
# We will assign the seventh entry (which corresponds to the target protein, coronavirus 3C-like proteinase) to the selected_target variable

# %%
# Select and retrieve bioactivity data for SARS coronavirus 3C-like proteinase (seventh entry)
selected_target = targets.target_chembl_id[6]
selected_target
# Out:
# 'CHEMBL3927'

# %% [markdown]
# Here, we are retrieving only the bioactivity data for coronavirus 3C-like proteinase (CHEMBL3927) that are reported as IC 50 values in nM (nanomolar) unit.
#
# **IC50 (Half-maximal Inhibitory Concentration)** is commonly used as a *measure of drug potency*. The concentration of a drug or inhibitor needed to inhibit a biological process or response by 50%.
# *The lower the IC50 value, the more potent the drug.*

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id = selected_target).filter(standard_type = "IC50")

# %%
df = pd.DataFrame.from_dict(res)
df.head(5)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None      1480935                  []
# 1        None             None      1480936                  []
# 2        None             None      1481061                  []
# 3        None             None      1481065                  []
# 4        None             None      1481066                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL829584  In vitro inhibitory concentration against SARS...
# 1    CHEMBL829584  In vitro inhibitory concentration against SARS...
# 2    CHEMBL830868  In vitro inhibitory concentration against SARS...
# 3    CHEMBL829584  In vitro inhibitory concentration against SARS...
# 4    CHEMBL829584  In vitro inhibitory concentration against SARS...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# ...

# %% [markdown]
# First we will check the unique entries for **standard_type** column in order to ensure that only IC50 type is present.

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data.csv', index = False)

# %% [markdown]
# ## **Copying files to Google Drive**

# %% [markdown]
# Firstly, we need to mount the Google Drive into Colab so that we can have access to our Google adrive from within Colab.

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount = True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Next, we create a folder in our Colab Notebooks folder on Google Drive.

# %%
# Create a folder named DrugDiscovery_Project
! mkdir "/content/gdrive/My Drive/Colab Notebooks/DrugDiscovery_Project"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/DrugDiscovery_Project’: File exists

# %%
# copy the bioactivity_data.csv file into the folder DrugDiscovery_Project
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/DrugDiscovery_Project"

# %% [markdown]
# Taking a glimpse of the **bioactivity_data.csv** file that we've just created.

# %%
# Let's see the CSV file that we have created.
! ls "/content/gdrive/My Drive/Colab Notebooks/DrugDiscovery_Project"
# Out:
# bioactivity_data.csv

# %%
! head bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ...

# %% [markdown]
# ## **Unmount Google drive from Colab**

# %%
from google.colab import drive
drive.flush_and_unmount()

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#     action_type activity_comment  activity_id activity_properties  \
# 0          None             None      1480935                  []
# 1          None             None      1480936                  []
# 2          None             None      1481061                  []
# 3          None             None      1481065                  []
# 4          None             None      1481066                  []
# ..          ...              ...          ...                 ...
# 128        None             None     12041507                  []
# 129        None             None     12041508                  []
# 130        None             None     12041509                  []
# 131        None             None     12041510                  []
# 132        None             None     12041511                  []
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL829584  In vitro inhibitory concentration against SARS...
# ...

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# Now we will select the ***molecule_chembl_id, canonical_smiles and standard_value*** from the dataframe to create a new *selection list* of all the entries including their bioactivity status.

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 128      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#     standard_value
# 0           7200.0
# 1           9400.0
# ...

# %% [markdown]
# In this df, we need to add the bioactivity data of the molecule using pd.conact() function.

# %%
processed_data = pd.concat([df3,pd.Series(bioactivity_class, name = 'bioactivity_class')],axis=1)

processed_data.head()
# Out:
#   molecule_chembl_id                                 canonical_smiles  \
# 0       CHEMBL187579           Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1       CHEMBL188487           O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2       CHEMBL185698          O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3       CHEMBL426082              O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4       CHEMBL187717  O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
#
#   standard_value bioactivity_class
# 0         7200.0      intermediate
# 1         9400.0      intermediate
# 2        13500.0          inactive
# 3        13110.0          inactive
# 4         2000.0      intermediate

# %% [markdown]
# Saves dataframe to CSV file

# %%
processed_data.to_csv('bioactivity_preprocessed_data.csv', index=False)

# %%
! head bioactivity_preprocessed_data.csv
# Out:
# molecule_chembl_id,canonical_smiles,standard_value,bioactivity_class
# CHEMBL187579,Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21,7200.0,intermediate
# CHEMBL188487,O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21,9400.0,intermediate
# CHEMBL185698,O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21,13500.0,inactive
# CHEMBL426082,O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21,13110.0,inactive
# CHEMBL187717,O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-],2000.0,intermediate
# CHEMBL365134,O=C1C(=O)N(Cc2cc3ccccc3s2)c2c(Br)cccc21,980.0,active
# CHEMBL187598,O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccc(F)cc21,4820.0,intermediate
# CHEMBL190743,O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccc(I)cc21,950.0,active
# CHEMBL365469,O=C1C(=O)N(Cc2cc3ccccc3s2)c2cccc(Cl)c21,11200.0,inactive

# %% [markdown]
# ### **Let's copy to the Google Drive**

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/DrugDiscovery_Project"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/DrugDiscovery_Project"
# Out:
# bioactivity_data.csv  bioactivity_preprocessed_data.csv

# %% [markdown]
# ===================================================================================================================
